# %%
import pandas as pd

# %%
melanoma_mutation_df = pd.read_csv("raw_dir/per_cancer_icgc/SKCM-US/simple_somatic_mutation.open.SKCM-US.tsv", 
                                   sep="\t")

# %%
melanoma_mutation_df
# Out:
#         icgc_mutation_id icgc_donor_id project_code icgc_specimen_id  \
# 0              MU4366706       DO37659      SKCM-US          SP82900
# 1              MU4366706       DO37659      SKCM-US          SP82900
# 2              MU4366706       DO37659      SKCM-US          SP82900
# 3              MU4366706       DO37659      SKCM-US          SP82900
# 4              MU4366706       DO37659      SKCM-US          SP82900
# ...                  ...           ...          ...              ...
# 3942801        MU4492923      DO219501      SKCM-US         SP120589
# 3942802        MU4492923      DO219501      SKCM-US         SP120589
# 3942803        MU4492923      DO219501      SKCM-US         SP120589
# 3942804        MU4492923      DO219501      SKCM-US         SP120589
# 3942805        MU4492923      DO219501      SKCM-US         SP120589
#
#         icgc_sample_id matched_icgc_sample_id           submitted_sample_id  \
# ...

# %%
melanoma_rna_seq_df = pd.read_csv("raw_dir/per_cancer_icgc/SKCM-US/exp_seq.SKCM-US.tsv", 
                                   sep="\t")

# %%
melanoma_rna_seq_df
# Out:
#         icgc_donor_id project_code icgc_specimen_id icgc_sample_id  \
# 0             DO37659      SKCM-US          SP82900       SA432551
# 1             DO37659      SKCM-US          SP82900       SA432551
# 2             DO37659      SKCM-US          SP82900       SA432551
# 3             DO37659      SKCM-US          SP82900       SA432551
# 4             DO37659      SKCM-US          SP82900       SA432551
# ...               ...          ...              ...            ...
# 8910449       DO38135      SKCM-US          SP83856       SA438587
# 8910450       DO38135      SKCM-US          SP83856       SA438587
# 8910451       DO38135      SKCM-US          SP83856       SA438587
# 8910452       DO38135      SKCM-US          SP83856       SA438587
# 8910453       DO38135      SKCM-US          SP83856       SA438587
#
#                   submitted_sample_id  analysis_id gene_model  gene_id  \
# 0        TCGA-DA-A1HV-06A-21R-A18S-07          738        GAF   AMOTL1
# ...

# %%
sizes = melanoma_rna_seq_df.groupby("icgc_donor_id").size()

# %%
sizes.value_counts()
# Out:
# 20531    426
# 41062      4
# dtype: int64

# %%
melanoma_mirna_seq_df = pd.read_csv("raw_dir/per_cancer_icgc/SKCM-US/mirna_seq.SKCM-US.tsv", 
                                   sep="\t")

# %%
temp = pd.read_csv("raw_dir/per_cancer_icgc/SKCM-US/donor.SKCM-US.tsv", sep="\t")

# %%
temp = pd.read_csv("raw_dir/per_cancer_icgc/SKCM-US/meth_array.SKCM-US.tsv.gz",sep="\t", nrows=100)

# %%
temp
# Out:
#    icgc_donor_id project_code icgc_specimen_id icgc_sample_id  \
# 0        DO37659      SKCM-US          SP82900       SA432545
# 1        DO37659      SKCM-US          SP82900       SA432545
# 2        DO37659      SKCM-US          SP82900       SA432545
# 3        DO37659      SKCM-US          SP82900       SA432545
# 4        DO37659      SKCM-US          SP82900       SA432545
# ..           ...          ...              ...            ...
# 95       DO37659      SKCM-US          SP82900       SA432545
# 96       DO37659      SKCM-US          SP82900       SA432545
# 97       DO37659      SKCM-US          SP82900       SA432545
# 98       DO37659      SKCM-US          SP82900       SA432545
# 99       DO37659      SKCM-US          SP82900       SA432545
#
#              submitted_sample_id  analysis_id  \
# 0   TCGA-DA-A1HV-06A-21D-A19B-05           72
# 1   TCGA-DA-A1HV-06A-21D-A19B-05           72
# 2   TCGA-DA-A1HV-06A-21D-A19B-05           72
# ...

# %%
melanoma_df.columns
# Out:
# Index(['icgc_mutation_id', 'icgc_donor_id', 'project_code', 'icgc_specimen_id',
#        'icgc_sample_id', 'matched_icgc_sample_id', 'submitted_sample_id',
#        'submitted_matched_sample_id', 'chromosome', 'chromosome_start',
#        'chromosome_end', 'chromosome_strand', 'assembly_version',
#        'mutation_type', 'reference_genome_allele', 'mutated_from_allele',
#        'mutated_to_allele', 'quality_score', 'probability', 'total_read_count',
#        'mutant_allele_read_count', 'verification_status',
#        'verification_platform', 'biological_validation_status',
#        'biological_validation_platform', 'consequence_type', 'aa_mutation',
#        'cds_mutation', 'gene_affected', 'transcript_affected',
#        'gene_build_version', 'platform', 'experimental_protocol',
#        'sequencing_strategy', 'base_calling_algorithm', 'alignment_algorithm',
#        'variation_calling_algorithm', 'other_analysis_algorithm',
# ...

# %%
melanoma_small_df = df[["chromosome_start", "chromosome_end"]]

# %%
melanoma_df
# Out:
#         icgc_mutation_id icgc_donor_id project_code icgc_specimen_id  \
# 0              MU4366706       DO37659      SKCM-US          SP82900
# 1              MU4366706       DO37659      SKCM-US          SP82900
# 2              MU4366706       DO37659      SKCM-US          SP82900
# 3              MU4366706       DO37659      SKCM-US          SP82900
# 4              MU4366706       DO37659      SKCM-US          SP82900
# ...                  ...           ...          ...              ...
# 3942801        MU4492923      DO219501      SKCM-US         SP120589
# 3942802        MU4492923      DO219501      SKCM-US         SP120589
# 3942803        MU4492923      DO219501      SKCM-US         SP120589
# 3942804        MU4492923      DO219501      SKCM-US         SP120589
# 3942805        MU4492923      DO219501      SKCM-US         SP120589
#
#         icgc_sample_id matched_icgc_sample_id           submitted_sample_id  \
# ...
