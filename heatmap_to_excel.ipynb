# %%
import pandas as pd

# %%
corrs = pd.read_csv("all_corrs.csv", index_col=0)

# %%
corrs
# Out:
#                                               Ovary-AdenoCA  CNS-PiloAstro  \
# Adipose Omentum Adipocyte                         -0.264525       0.381291
# Adipose Omentum Endothelial Cell (General) 1      -0.264089       0.328279
# Adipose Omentum Endothelial Cell (General) 2      -0.350038       0.443357
# Adipose Omentum Fibroblast (General)              -0.253428       0.385511
# Adipose Omentum Lymphatic Endothelial Cell        -0.262863       0.374654
# ...                                                     ...            ...
# Vagina Smooth Muscle (GE Junction)                -0.275167       0.521621
# Vagina Smooth Muscle (General)                     1.600725      -0.334314
# Vagina Smooth Muscle (Uterine)                    -0.369337       0.450642
# Vagina Smooth Muscle (Vaginal)                    -0.266100       0.456667
# Vagina T Lymphocyte 1 (CD8+)                       0.183953       0.804156
#
# ...

# %%
(corrs.style.background_gradient(cmap='seismic')
           .to_excel("corr_matrix.xlsx", engine="openpyxl"))
